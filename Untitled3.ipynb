# %%
import pandas as pd

df = pd.read_csv('C:\\cleaning data\\dataset\\train.csv')
df.head(50)
# Out:
#     instance_id                                         track_name  \
# 0   MSC_83537.0                              Estrellitas y Duendes
# 1   MSC_22044.0                                           Al Norte
# 2   MSC_62017.0                   Yeah! (feat. Lil Jon & Ludacris)
# 3   MSC_76365.0                                      Can’t You See
# 4   MSC_71493.0              Sonata III (G Moll), BWV 1029: Adagio
# 5   MSC_30580.0                              Una Pàgina per Chopin
# 6   MSC_28346.0                                          Love More
# 7   MSC_33942.0              I Think I ll Just Stay Here And Drink
# 8   MSC_25657.0                                      Juke Box Hero
# 9   MSC_54552.0                              Shine on Harvest Moon
# 10  MSC_54638.0                               Put Your Money On Me
# 11  MSC_82740.0                     Built My Legacy (feat. Offset)
# 12  MSC_86737.0                                I Wanna Be Somebody
# ...

# %%
df.head(50)
# Out:
#     instance_id                                         track_name  \
# 0   MSC_83537.0                              Estrellitas y Duendes
# 1   MSC_22044.0                                           Al Norte
# 2   MSC_62017.0                   Yeah! (feat. Lil Jon & Ludacris)
# 3   MSC_76365.0                                      Can’t You See
# 4   MSC_71493.0              Sonata III (G Moll), BWV 1029: Adagio
# 5   MSC_30580.0                              Una Pàgina per Chopin
# 6   MSC_28346.0                                          Love More
# 7   MSC_33942.0              I Think I ll Just Stay Here And Drink
# 8   MSC_25657.0                                      Juke Box Hero
# 9   MSC_54552.0                              Shine on Harvest Moon
# 10  MSC_54638.0                               Put Your Money On Me
# 11  MSC_82740.0                     Built My Legacy (feat. Offset)
# 12  MSC_86737.0                                I Wanna Be Somebody
# ...

# %%
df.isnull().sum()
# Out:
# instance_id          0
# track_name           0
# popularity           0
# acousticness         0
# danceability         0
# duration_ms          0
# energy               0
# instrumentalness     0
# key                  0
# liveness             0
# loudness             0
# voice_gender         0
# mode                 0
# speechiness          0
# tempo                0
# musician_category    0
# valence              0
# music_genre          0
# dtype: int64

# %%
df['valence'].mean()
# Out:
# 0.4512428521310768

# %%
df['valence'].median()
# Out:
# 0.4315219344630521

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.scatter(df['music_genre'],df['valence'])

# %%
df['valence'].fillna(method='ffill',inplace=True)

# %%
df['valence'].isnull().sum()
# Out:
# 0

# %%
df['musician_category'].value_counts()
# Out:
# Band    5302
# Solo    5243
# Duet    5136
# Name: musician_category, dtype: int64

# %%
df['musician_category'].fillna(method='ffill',inplace=True)

# %%
df['tempo'].value_counts()
# Out:
# 100.014               0.000446
# 118.00399999999999    0.000446
# 100.00299999999999    0.000446
# 139.997               0.000446
# 105.01700000000001    0.000383
#                         ...
# 108.97200000000001    0.000064
# 106.01700000000001    0.000064
# 80.90100000000001     0.000064
# 117.52799999999999    0.000064
# 94.2                  0.000064
# Name: tempo, Length: 12331, dtype: float64

# %%
df['tempo'].replace(to_replace='?',method='ffill',inplace=True)
df['tempo'].replace(to_replace='?',method='bfill',inplace=True)

# %%
df['tempo'].median()
# Out:
# 113.027

# %%
df['tempo'].isnull().sum()
# Out:
# 0

# %%
df['speechiness'].fillna(method='ffill',inplace=True)

# %%
df['speechiness'].isnull().sum()
# Out:
# 0

# %%
df['speechiness'].mean()
# Out:
# 0.09641753599346986

# %%
df['speechiness'].median()
# Out:
# 0.0504272101408535

# %%
sns.boxplot(df['speechiness'])
# Out:
# c:\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='speechiness'>

# %%
df['speechiness'] = [0.140 if x > 0.140 else x for x in df['speechiness']]

df['speechiness'].mean()
# Out:
# 0.06925356481846637

# %%
df['mode'].value_counts()
# Out:
# 1    9230
# 2    5370
# 0    1081
# Name: mode, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

LB = LabelEncoder()

df['mode'] = LB.fit_transform(df['mode'])

# %%
df['mode'] = LB.inverse_transform(df['mode'])

# %%
df['mode'].fillna(method='ffill',inplace=True)

# %%
df['voice_gender'].value_counts()
# Out:
# Female    5050
# Male      4953
# Both      4913
# Name: voice_gender, dtype: int64

# %%
df['voice_gender'] = LB.fit_transform(df['voice_gender'])

# %%
df['voice_gender'].fillna(method='ffill',inplace=True)

# %%
df['voice_gender'] = LB.fit_transform(df['voice_gender'])

# %%
df['loudness'].fillna(method='ffill',inplace=True)

# %%
sns.boxplot(df['loudness'])
# Out:
# c:\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='loudness'>

# %%
df['loudness'].mean()
# Out:
# -11.399289586123334

# %%
df['loudness'].median()
# Out:
# -8.612

# %%
df['loudness'] = [-30 if x < -30 else x for x in df['loudness']]

# %%
sns.boxplot(df['liveness'])
# Out:
# c:\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='liveness'>

# %%
df['liveness'].mean()
# Out:
# 0.18249767826528812

# %%
df['liveness'].median()
# Out:
# 0.128783982794973

# %%
df['liveness'] = [0.5 if x > 0.5 else x for x in df['liveness']]

# %%
df['key'] = LB.fit_transform(df['key'])

# %%
df['instrumentalness'].fillna(method='ffill',inplace=True)

# %%
df['instrumentalness'].mean()
# Out:
# 0.26465622181233206

# %%
df['instrumentalness'].median()
# Out:
# 0.0007386963188752

# %%
sns.boxplot(df['instrumentalness'])
# Out:
# c:\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='instrumentalness'>

# %%
df['instrumentalness'].value_counts()
# Out:
# 0.000000    4389
# 0.921094       3
# 0.000058       2
# 0.925545       2
# 0.938100       2
#             ...
# 0.911462       1
# 0.488307       1
# 0.009966       1
# 0.000011       1
# 0.502878       1
# Name: instrumentalness, Length: 11219, dtype: int64

# %%
plt.scatter(df['instrumentalness'],df['music_genre'])

# %%
for x in df.index:
    if df['music_genre'][x] == 'Hip-Hop':
        if df['instrumentalness'][x] > 0.2:
            df['instrumentalness'][x] = 0.2
        if df['danceability'][x] < 0.3:
            df['danceability'][x] = 0.3
    
    if df['music_genre'][x] == 'Country':
        if df['instrumentalness'][x] > 0.3:
            df['instrumentalness'][x] = 0.3
        if df['danceability'][x] < 0.3:
            df['danceability'][x] = 0.3
# Out:
# C:\Users\TANU\AppData\Local\Temp/ipykernel_920/4185527032.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['danceability'][x] = 0.3
# C:\Users\TANU\AppData\Local\Temp/ipykernel_920/4185527032.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['danceability'][x] = 0.3

# %%
df['instrumentalness'].isnull().sum()
# Out:
# 0

# %%
df['energy'] = df2['energy']

# %%
df1['energy'].mean()
# Out:
# 0.4269766268413185

# %%
df['energy'].median()
# Out:
# 0.5603888618769901

# %%
sns.boxplot(df['energy'])
# Out:
# c:\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='energy'>

# %%
df['energy'].value_counts()
# Out:
# 0.000000    1217
# 0.192107       1
# 0.373362       1
# 0.880433       1
# 0.181896       1
#             ...
# 0.556784       1
# 0.476055       1
# 0.644131       1
# 0.909193       1
# 0.470057       1
# Name: energy, Length: 14371, dtype: int64

# %%
df['energy'] = [0 if x < 0 else x for x in df['energy']]

# %%
df['energy'].fillna(method='ffill',inplace=True)

# %%
df['duration_ms'].mean()
# Out:
# 248106.36181716726

# %%
df['duration_ms'].median()
# Out:
# 236288.697

# %%
sns.boxplot(df['duration_ms'])
# Out:
# c:\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='duration_ms'>

# %%
plt.scatter(df['music_genre'],df['duration_ms'])

# %%
df['duration_ms'] = [2018949.601 if x > 2018949.601 else x for x in df['duration_ms']]

# %%
df['duration_ms'].nlargest(10)
# Out:
# 5392     3410383.324
# 9339     2459588.224
# 1138     2018949.601
# 14340    1933549.008
# 13854    1726383.924
# 6607     1703101.694
# 6693     1685765.375
# 5959     1575037.801
# 7457     1551004.232
# 6940     1536972.586
# Name: duration_ms, dtype: float64

# %%
df['duration_ms'].fillna(method='ffill',inplace=True)

# %%
df['danceability'].mean()
# Out:
# 0.5701058631606808

# %%
df['danceability'].median()
# Out:
# 0.5861135203802297

# %%
df['danceability'].fillna(method='ffill',inplace=True)

# %%
plt.scatter(df['music_genre'],df['danceability'])

# %%
df['popularity'].mean()
# Out:
# 50.80969810598813

# %%
df['popularity'].median()
# Out:
# 54.105

# %%
df['popularity'].fillna(method='ffill',inplace=True)

# %%
plt.scatter(df['popularity'],df['music_genre'])

# %%
df['musician_category'] = LB.fit_transform(df['musician_category'])

# %%
X=df.iloc[:,2:17]
Y=df.iloc[:,-1]


corrmat = df.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
#plot heat map
g=sns.heatmap(df[top_corr_features].corr(),annot=True)

# %%
features = df.drop(['speechiness','mode','voice_gender','liveness','key','musician_category','music_genre','instance_id','track_name','tempo','duration_ms'],axis=1)

# %%
df['tempo'].describe()
# Out:
# count       15681
# unique      12331
# top       100.014
# freq            7
# Name: tempo, dtype: object

# %%
features
# Out:
#        popularity  acousticness  danceability    energy  instrumentalness  \
# 0          49.178      0.970522      0.580508  0.192107          0.000000
# 1          59.827      1.009380      0.687542  0.265942          0.000031
# 2          89.023      0.020041      0.967948  0.857411          0.000000
# 3          55.762      0.010284      0.616287  0.970513          0.000220
# 4          45.095      0.858769      0.280645  0.114732          0.002753
# ...           ...           ...           ...       ...               ...
# 15676       0.000      0.866988      0.387476  0.196799          0.028725
# 15677      40.514      0.883333      0.459917  0.349263          0.000519
# 15678      35.082      0.905281      0.566619  0.543673          0.209238
# 15679      59.693      0.113408      0.644554  0.912201          0.000089
# 15680      56.518      0.847136      0.502160  0.470057          0.502878
#
#        loudness   valence
# 0       -14.140  0.598965
# ...

# %%
target = df['music_genre']

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score

RFC = RandomForestClassifier(n_estimators=25,criterion='gini')

clf = cross_val_score(RFC,features,target,cv=10)

clf.mean()
# Out:
# 0.7109238628529806

# %%
from xgboost import XGBClassifier

XGB = XGBClassifier()

clf1 = cross_val_score(XGB,features,target)

clf1.mean()
# Out:
# c:\python39\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [22:52:53] WARNING: D:\Build\xgboost\xgboost-1.5.1.git\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

X_train,X_test,y_train,y_test = train_test_split(features,target)

RFC.fit(X_train,y_train)

y_pred=RFC.predict(X_test)


accuracy_score(y_test,y_pred)
# Out:
# 0.7214996174445295
